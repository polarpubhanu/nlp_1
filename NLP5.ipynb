# %% [markdown]
# <a href="https://colab.research.google.com/github/polarpubhanu/nlp_1/blob/main/NLP5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
nltk.download('punkit')
# Out:
# [nltk_data] Error loading punkit: Package 'punkit' not found in index
# False

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
para = """India vs New Zealand 4th T20 LIVE Score Updates: Tim Seifert after POTM
(On the boundaries off top-edge at the start of his innings) Sometimes you get a bit lucky early on and yeah sometimes the nature of the game, but the intent that we wanted to put on the bowlers early, sometimes you get a couple of top-edges and they go for boundary early. Look, he’s (Bumrah) got me with a beauty last game, so sometimes you’ve got to tip your hat, but you’ve just got to make sure that you look to play straight in the right line and then once you get that first ball, I reckon with him, then it’s a bit easier. (Bat differently today?) I wouldn’t say a huge amount, to be honest. Sometimes you get some and others you don’t. And that’s the nature of T20 cricket, but the intent and putting pressure on the bowlers, that’s the main thing that we want to do. No matter where we play, the next game and the World Cup, every wicket’s going to be a bit different. So being able to adapt, but being true to yourself and putting pressure on the bowlers. I think if we look at the wickets, the pitches are going to be anything like this series, they’re going to be high-scoring. So you’ve just got to keep that intent up"""

# %%
sentence = nltk.sent_tokenize(para)

# %%
sentence
# Out:
# ['India vs New Zealand 4th T20 LIVE Score Updates: Tim Seifert after POTM\n(On the boundaries off top-edge at the start of his innings) Sometimes you get a bit lucky early on and yeah sometimes the nature of the game, but the intent that we wanted to put on the bowlers early, sometimes you get a couple of top-edges and they go for boundary early.',
#  'Look, he’s (Bumrah) got me with a beauty last game, so sometimes you’ve got to tip your hat, but you’ve just got to make sure that you look to play straight in the right line and then once you get that first ball, I reckon with him, then it’s a bit easier.',
#  '(Bat differently today?)',
#  'I wouldn’t say a huge amount, to be honest.',
#  'Sometimes you get some and others you don’t.',
#  'And that’s the nature of T20 cricket, but the intent and putting pressure on the bowlers, that’s the main thing that we want to do.',
#  'No matter where we play, the next game and the World Cup, every wicket’s going to be a bit different.',
#  'So being able to adapt, but being true to yourself and putting pressure on the bowlers.',
#  'I think if we look at the wickets, the pitches are going to be anything like this series, they’re going to be high-scoring.',
#  'So you’ve just got to keep that intent up']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %%
for i in range(len(sentence)):
  words = nltk.word_tokenize(sentence[i])
  words = [stemmer.stem(word) for word in words]
  sentence[i] = ''.join(words)

# %%
sentence
# Out:
# ['indiavsnewzealand4tht20livescoreupdat:timseifertafterpotm(ontheboundariofftop-edgatthestartofhiinning)sometimyougetabitluckiearlionandyeahsometimthenaturofthegame,buttheintentthatwewanttoputonthebowlerearli,sometimyougetacouploftop-edgandtheygoforboundariearli.',
#  'look,he’s(bumrah)gotmewithabeautilastgame,sosometimyou’vegottotipyourhat,butyou’vejustgottomakesurethatyoulooktoplaystraightintherightlineandthenoncyougetthatfirstball,ireckonwithhim,thenit’sabiteasier.',
#  '(batdiffertoday?)',
#  'iwouldn’tsayahugeamount,tobehonest.',
#  'sometimyougetsomeandotheryoudon’t.',
#  'andthat’sthenaturoft20cricket,buttheintentandputpressuronthebowler,that’sthemainthingthatwewanttodo.',
#  'nomatterwhereweplay,thenextgameandtheworldcup,everiwicket’sgotobeabitdiffer.',
#  'sobeabltoadapt,butbetruetoyourselfandputpressuronthebowler.',
#  'ithinkifwelookatthewicket,thepitcharegotobeanythlikethiseri,they’regotobehigh-scor.',
#  'soyou’vejustgottokeepthatintentup']

# %%
from nltk.stem import WordNetLemmatizer

# %%
para1 = """India vs New Zealand 4th T20 LIVE Score Updates: Tim Seifert after POTM
(On the boundaries off top-edge at the start of his innings) Sometimes you get a bit lucky early on and yeah sometimes the nature of the game, but the intent that we wanted to put on the bowlers early, sometimes you get a couple of top-edges and they go for boundary early. Look, he’s (Bumrah) got me with a beauty last game, so sometimes you’ve got to tip your hat, but you’ve just got to make sure that you look to play straight in the right line and then once you get that first ball, I reckon with him, then it’s a bit easier. (Bat differently today?) I wouldn’t say a huge amount, to be honest. Sometimes you get some and others you don’t. And that’s the nature of T20 cricket, but the intent and putting pressure on the bowlers, that’s the main thing that we want to do. No matter where we play, the next game and the World Cup, every wicket’s going to be a bit different. So being able to adapt, but being true to yourself and putting pressure on the bowlers. I think if we look at the wickets, the pitches are going to be anything like this series, they’re going to be high-scoring. So you’ve just got to keep that intent up"""

# %%
sentence1 = nltk.sent_tokenize(para1)

# %%
lemmatizer=WordNetLemmatizer()

# %%
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import wordnet
print(wordnet.synsets('computer'))
# Out:
# [Synset('computer.n.01'), Synset('calculator.n.01')]

# %%
import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

for i in range(len(sentence1)):
    words = nltk.word_tokenize(sentence1[i])
    newwords = [lemmatizer.lemmatize(word) for word in words]
    sentence1[i] = ' '.join(newwords)

# %%
sentence1
# Out:
# ['India v New Zealand 4th T20 LIVE Score Updates : Tim Seifert after POTM ( On the boundary off top-edge at the start of his inning ) Sometimes you get a bit lucky early on and yeah sometimes the nature of the game , but the intent that we wanted to put on the bowler early , sometimes you get a couple of top-edges and they go for boundary early .',
#  'Look , he ’ s ( Bumrah ) got me with a beauty last game , so sometimes you ’ ve got to tip your hat , but you ’ ve just got to make sure that you look to play straight in the right line and then once you get that first ball , I reckon with him , then it ’ s a bit easier .',
#  '( Bat differently today ? )',
#  'I wouldn ’ t say a huge amount , to be honest .',
#  'Sometimes you get some and others you don ’ t .',
#  'And that ’ s the nature of T20 cricket , but the intent and putting pressure on the bowler , that ’ s the main thing that we want to do .',
#  'No matter where we play , the next game and the World Cup , every wicket ’ s going to be a bit different .',
#  'So being able to adapt , but being true to yourself and putting pressure on the bowler .',
#  'I think if we look at the wicket , the pitch are going to be anything like this series , they ’ re going to be high-scoring .',
#  'So you ’ ve just got to keep that intent up']

# %%
para3 = """"India vs New Zealand 4th T20 LIVE Score Updates: Tim Seifert after POTM
(On the boundaries off top-edge at the start of his innings) Sometimes you get a bit lucky early on and yeah sometimes the nature of the game, but the intent that we wanted to put on the bowlers early, sometimes you get a couple of top-edges and they go for boundary early. Look, he’s (Bumrah) got me with a beauty last game, so sometimes you’ve got to tip your hat, but you’ve just got to make sure that you look to play straight in the right line and then once you get that first ball, I reckon with him, then it’s a bit easier. (Bat differently today?) I wouldn’t say a huge amount, to be honest. Sometimes you get some and others you don’t. And that’s the nature of T20 cricket, but the intent and putting pressure on the bowlers, that’s the main thing that we want to do. No matter where we play, the next game and the World Cup, every wicket’s going to be a bit different. So being able to adapt, but being true to yourself and putting pressure on the bowlers. I think if we look at the wickets, the pitches are going to be anything like this series, they’re going to be high-scoring. So you’ve just got to keep that intent up"""

# %%
word = nltk.word_tokenize(para3)

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk

words = nltk.word_tokenize("Natural Language Processing is interesting")
tag_word = nltk.pos_tag(words)

# %%
tag_word
# Out:
# [('Natural', 'JJ'),
#  ('Language', 'NNP'),
#  ('Processing', 'NNP'),
#  ('is', 'VBZ'),
#  ('interesting', 'VBG')]

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {"hadn't", 'because', "hasn't", 'some', "mustn't", 'wouldn', 'couldn', 'd', 'has', 'very', "it's", "isn't", 'your', "mightn't", 'again', 'both', 'am', "i'd", 'yours', "don't", "it'd", 'are', 'needn', "we've", 'all', 'and', 'these', 'me', 'being', 'into', 'same', 'in', 'doesn', 'i', "shan't", 'did', 'it', 'yourself', 'those', 'wasn', 'most', 'each', 'of', 'just', 'we', 'at', 'or', 's', 'should', 'whom', "i'm", "couldn't", 'ours', "she'll", 'over', 'up', 'with', 'as', 'when', 'yourselves', 'which', 'who', 'so', 'hadn', "he's", "should've", 'its', "they'd", "i'll", "aren't", 'didn', 'don', 'further', 'during', 'my', 'any', 'than', 'that', "he'd", 'their', "you've", 'own', 'about', "i've", 've', "you'll", 'can', 'had', 'shouldn', 'through', 'won', 'not', 'below', 'isn', 'she', "they're", "she'd", "haven't", 'aren', 'been', 'themselves', 'such', "we're", 'from', 'his', 'on', 'only', 'what', "you'd", "weren't", 'itself', 'but', 'here', 'hasn', 'against', "needn't", 'until', 'herself', 'be', 'if', 'under', "that'll", 'have', 'there', "shouldn't", 'how', "wouldn't", 'does', "he'll", "she's", 'them', 'once', 'him', 'will', 'haven', 'they', 'is', 'down', "it'll", 'weren', "didn't", 'having', 'for', 'himself', 'no', 'an', "they've", "wasn't", 't', 'too', 'a', 'to', 'out', 'nor', "we'd", 'above', 'was', 'o', 'theirs', 'off', 'then', 'y', 'll', 'why', 'after', 'now', "they'll", 'other', 'ain', 'the', 'ma', 're', 'do', 'more', "doesn't", 'few', 'you', 'shan', 'between', 'by', 'this', 'before', 'mightn', 'our', 'm', "you're", "we'll", 'doing', 'mustn', 'were', 'he', 'myself', "won't", 'her', 'hers', 'ourselves', 'where', 'while'}

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

sentence = "Natural Language Processing is very interesting and useful"

words = word_tokenize(sentence)
stop_words = set(stopwords.words('english'))

filtered_words = [word for word in words if word.lower() not in stop_words]

print(filtered_words)
# Out:
# ['Natural', 'Language', 'Processing', 'interesting', 'useful']

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import nltk

sentence = "Barack Obama was born in Hawaii"

words = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(words)
named_entities = nltk.ne_chunk(pos_tags)

print(named_entities)
# Out:
# (S
#   (PERSON Barack/NNP)
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Hawaii/NNP))
